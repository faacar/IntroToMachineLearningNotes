# %% [raw]
# #Python Review

# %%
varNum = 10
varStr = "week1"
varFloat = 11.0

print(type(varNum))
print(type(varStr))
print(type(varFloat))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
list = [1, 2, 3 ,4 ,8]
listCity = ["Istanbul", "Ankara", "Izmir"]
type(listCity)
# Out:
# list

# %%
listNum = list[1]
listFilter = list[0: 3]
cityLast = listCity[-1]
print(cityLast)
# Out:
# Izmir

# %%
list.append(5)
print(list)
listCity.reverse()
print(listCity)
list.sort()
print(list)
# Out:
# [1, 2, 3, 4, 8, 5]
# ['Izmir', 'Ankara', 'Istanbul']
# [1, 2, 3, 4, 5, 8]

# %%
for each in listCity:
    print(each)
max(list)
# Out:
# Izmir
# Ankara
# Istanbul
# 8

# %%
if len(listCity):
    print("you have 3 cities in list")
else:
    print("dont know how many city you have")
# Out:
# you have 3 cities in list

# %%
i = 0
while (i < 5):
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
