# %%
#week 3

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Örnek veri
data = sns.load_dataset("flights") 
data = data.pivot("month", "year", "passengers")

# Heatmap
sns.heatmap(data=data, annot=True, fmt="d", cmap="YlGnBu")

plt.show()

# %%
data = sns.load_dataset("flights") 
# swarm plot
sns.swarmplot(x="year",y="passengers",data=data)
plt.show()

# %%
data = sns.load_dataset("flights")

# Line plot
sns.lineplot(x="year", y="passengers",data=data)

plt.show()

# %%
data = sns.load_dataset("iris")

sns.swarmplot(x="species", y="petal_length", data=data)

plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:3544: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data = sns.load_dataset("titanic")

# Bar plot
sns.countplot(data=data, x="sex")

plt.show()

# %%
data = pd.DataFrame({
    'age_group': np.repeat(['18-30', '31-45', '46-60', '61+'], 100),
    'feedback_rating': np.random.randint(1, 6, 400)
})

# FacetGrid oluşturma
g = sns.FacetGrid(data, col="age_group", margin_titles=True)

# Grafik tipi
g.map(sns.histplot, "feedback_rating")

# %%
np.random.seed(0)
data = pd.DataFrame({'A': np.random.randn(100),
                     'B': np.random.choice(['X', 'Y'], size=100),
                     'C': np.random.randint(0, 10, size=100)})

g = sns.FacetGrid(data, col='B', col_wrap=2)
g.map(sns.histplot, 'A')

# %%
np.random.seed(0)
data = pd.DataFrame({'A': np.random.randn(100),
                     'B': np.random.choice(['X', 'Y'], size=100),
                     'C': np.random.randint(0, 10, size=100)})

# FacetGrid oluşturarak grafiği ayarlayalım
g = sns.FacetGrid(data, col='B', col_wrap=2)
g.map(sns.lineplot, 'C', 'A')

# %%
sns.set_theme(style="white")

df = sns.load_dataset("penguins")

g = sns.JointGrid(data=df, x="body_mass_g", y="bill_depth_mm", space=0)
g.plot_joint(sns.kdeplot,
             fill=True, clip=((2200, 6800), (10, 25)),
             thresh=0, levels=100, cmap="rocket")
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)

# %%
import seaborn as sns

sns.set_theme(style="darkgrid")

df = sns.load_dataset("tips")

g = sns.JointGrid(data=df, x="total_bill", y="tip", space=0, marginal_ticks=10)
g.plot_joint(sns.kdeplot,
             fill=True, clip=((0, 60), (0, 10)),
             thresh=0, levels=100, cmap="mako")
g.plot_marginals(sns.histplot, color="#242526", alpha=1, bins=20)

# %%
# data_science

# %%
data = sns.load_dataset("titanic")

categorical = data.dtypes[data.dtypes == "object"].index
print(categorical)

data[categorical].describe()
# Out:
# Index(['sex', 'embarked', 'who', 'embark_town', 'alive'], dtype='object')
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
data["age"].describe()

#empy age values
missing = np.where(data["age"].isnull() == True)
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
sns.jointplot(data=data, x="age", y="fare", kind="kde")

# %%
sns.ecdfplot(data=data, x="age")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Proportion'>

# %%
data.hist(column='age', figsize=(9,6), bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'age'}>]], dtype=object)
